# %% [markdown]
# https://www.animeboston.com/schedule/index/2025

# %% [markdown]
# # Notes
#
# - Careful for time slots, verify everything lines up (triple check) don't want a repeat of what happened last time Johnny boy
# - Also, are there missing events? Verify that all events are accounted for...
# - - I am noticing some dropoff of events... Check rows and make sure we are all accounted for. For example original tables

# %%
import pandas as pd
import ast  # convert string list

# %% [markdown]
# ### Notes this is for refreshing and debugging

# %%
# Run when refreshing data!!!!!!!
# %run WebScraping.py # Refreshes all the original tables

# %%
# Run when refreshing data!!!!!!!
# %run WebScraping.py # Refreshes all the original tables

## Last updated (Tables 0, 1, 2)
# Friday, May 23rd, 2025
#   Last Updated: Wed, 05/14/2025, 2:28 pm
# Saturday, May 24th, 2025
#   Last Updated: Thu, 05/15/2025, 6:00 pm
# Sunday, May 25th, 2025
#   Last Updated: Tue, 05/13/2025, 7:45 pm



# #Run when needing to overwrite any new events or whatnot
# categories_JRW = pd.read_csv("Event_Categories_JRW.csv").drop(columns={'Color','Data Value'})
# categories_JRW['Category'] = categories_JRW['Category'].str.strip() # clean merge

# for ii in range(0, 3):
#     df_final = pd.read_csv(f"AnimeBoston_day{ii}_schedule.csv", converters={'TimeSlot': ast.literal_eval})
#     df_final['Category'] = df_final['Category'].str.strip() # clean merge
#     df_merge = pd.merge(df_final, categories_JRW, on='Category', how='left')
#     df_merge.to_csv(f"AnimeBoston_day{ii}_schedule_JRW.csv", index=False, encoding='utf-8-sig')

# dfs = []
# for ii in range(3):# loop over days
#     # read each file
#     df = pd.read_csv(f'AnimeBoston_day{ii}_schedule_JRW.csv')
#     dfs.append(df)

# # combine all days
# df_all = pd.concat(dfs, ignore_index=True)

# # filter NaN Utility
# df_nan_utility = df_all[df_all['Utility_general_JRW'].isna()]
# df_nan_utility

# %% [markdown]
# ### What's next
#
# Would be nice, best practice, can be later
# - Afterward, there is a checking process for seeing unique constraints on the time slots, this could be a function or some such

# %%
df_final = pd.read_csv(f"AnimeBoston_day{0}_schedule.csv", encoding='utf-8', converters={'TimeSlot': ast.literal_eval})

# %%
df_final_exploded = df_final.explode('TimeSlot').sort_values(by=['Room', 'Event']).reset_index(drop=True)
df_final_exploded
# Out:
#                Event                              Room  Utility_JW  \
# 0       Charity Ball           ('Hynes', 'Ballroom A')         0.0
# 1       Charity Ball           ('Hynes', 'Ballroom A')         0.0
# 2       Charity Ball           ('Hynes', 'Ballroom A')         0.0
# 3       Charity Ball           ('Hynes', 'Ballroom A')         0.0
# 4       Charity Ball           ('Hynes', 'Ballroom A')         0.0
# ..               ...                               ...         ...
# 744  Sketchbook Swap  ('Sheraton', 'Workshop Fairfax')         6.5
# 745  Sketchbook Swap  ('Sheraton', 'Workshop Fairfax')         6.5
# 746  Sketchbook Swap  ('Sheraton', 'Workshop Fairfax')         6.5
# 747  Sketchbook Swap  ('Sheraton', 'Workshop Fairfax')         6.5
# 748  Sketchbook Swap  ('Sheraton', 'Workshop Fairfax')         6.5
#
#                   Category    Color TimeSlot
# 0                    Dance  #CCFFFF    16:30
# 1                    Dance  #CCFFFF    16:45
# 2                    Dance  #CCFFFF    17:00
# 3                    Dance  #CCFFFF    17:15
# 4                    Dance  #CCFFFF    17:30
# ..                     ...      ...      ...
# 744  Social Event|Workshop  #F7931E    17:45
# 745  Social Event|Workshop  #F7931E    18:00
# 746  Social Event|Workshop  #F7931E    18:15
# 747  Social Event|Workshop  #F7931E    18:30
# 748  Social Event|Workshop  #F7931E    18:45
#
# [749 rows x 6 columns]

# %%
df_final_timeslotgrouped = df_final_exploded.groupby(['TimeSlot'])[['Event']].agg(set).reset_index()
df_final_timeslotgrouped
# Out:
#    TimeSlot                                              Event
# 0     00:00  {F-Bombs for Charity, DEG 201: Advanced Hentai...
# 1     00:15  {F-Bombs for Charity, DEG 201: Advanced Hentai...
# 2     00:30  {Slumber Party, Taskmaster, Pyramid Head Has a...
# 3     00:45  {Slumber Party, Taskmaster, Pyramid Head Has a...
# 4     01:00  {Fanservice & Ecchi AMVs, Pyramid Head Has a P...
# ..      ...                                                ...
# 67    22:45  {Chained Soldier (18+), Hentai by Women, for W...
# 68    23:00  {Cosplay Horror Stories (18+), Chained Soldier...
# 69    23:15  {Cosplay Horror Stories (18+), Chained Soldier...
# 70    23:30  {Cosplay Horror Stories (18+), Chained Soldier...
# 71    23:45  {Cosplay Horror Stories (18+), Chained Soldier...
#
# [72 rows x 2 columns]

# %%
# keep only first duplicates
# make Event lists hashable for deduplication
df_final_timeslotgrouped["Event_tuple"] = df_final_timeslotgrouped["Event"].apply(tuple)

# drop duplicates based on the Event list only, keeping the first time slot
df_dedupped_by_event = df_final_timeslotgrouped.drop_duplicates(subset="Event_tuple", keep="first")

# drop the helper column
df_dedupped_by_event = df_dedupped_by_event.drop(columns="Event_tuple").reset_index()
df_dedupped_by_event
# Out:
#     index TimeSlot                                              Event
# 0       0    00:00  {F-Bombs for Charity, DEG 201: Advanced Hentai...
# 1       2    00:30  {Slumber Party, Taskmaster, Pyramid Head Has a...
# 2       4    01:00  {Fanservice & Ecchi AMVs, Pyramid Head Has a P...
# 3       6    01:30  {Intro to J-horror, Taskmaster, Fanservice & E...
# 4       8    08:00                  {Samurai Troopers Ronin Warriors}
# 5      12    09:00  {Jam Zone: Sora, From Screen to Kitchen: Adapt...
# 6      14    09:30  {Jam Zone: Sora, From Screen to Kitchen: Adapt...
# 7      16    10:00  {Opening Ceremonies, Pokemon Gathering, The Hi...
# 8      18    10:30  {Opening Ceremonies, Pokemon Gathering, Tradit...
# 9      20    11:00  {A Beginner's Guide to Idol Dance, Opening Cer...
# 10     22    11:30  {A Beginner's Guide to Idol Dance, Let's $ew! ...
# 11     24    12:00  {Let's $ew! Dino Nuggies!, There’s a Live Acti...
# 12     26    12:30  {Let's $ew! Dino Nuggies!, A Look at Anime in ...
# 13     28    13:00  {Let's $ew! a Ditto!, Meet Kaiji Tang, Cosplay...
# 14     30    13:30  {Let's $ew! a Ditto!, Meet Kaiji Tang, Cosplay...
# 15     32    14:00  {Lovely Complex, Let's $ew! a Ditto!, Cosplay ...
# 16     33    14:15  {Lovely Complex, Let's $ew! a Ditto!, Cosplay ...
# 17     34    14:30  {Lovely Complex, Let's $ew! a Ditto!, Cosplay ...
# 18     36    15:00  {Girls Band Panel: Celebrating 10 Years of Ban...
# 19     37    15:15  {Girls Band Panel: Celebrating 10 Years of Ban...
# 20     38    15:30  {Western Animation Voice Acting and Anime Dubb...
# 21     40    16:00  {Western Animation Voice Acting and Anime Dubb...
# 22     42    16:30  {Meet Ayamine-sensei: Behind The Feisty Omega ...
# 23     43    16:45  {Meet Ayamine-sensei: Behind The Feisty Omega ...
# 24     44    17:00  {Idoling IRL: A Survival Guide for Beginners, ...
# 25     46    17:30  {Charity Ball, BL Bang Marry Kill, Burlesque S...
# 26     48    18:00  {Harlequin Manga : translating romance for Jap...
# 27     50    18:30  {American 'Anime' That Time Forgot, Harlequin ...
# 28     52    19:00  {American 'Anime' That Time Forgot, By the Bla...
# 29     54    19:30  {Anime Jeopardy! , By the Blade of Knights: 20...
# 30     55    19:45  {Anime Jeopardy! , By the Blade of Knights: 20...
# 31     56    20:00  {Anime Jeopardy! , Urusei Yatsura (Season 3), ...
# 32     58    20:30  {Urusei Yatsura (Season 3), Pretty Cure: The B...
# 33     59    20:45  {Urusei Yatsura (Season 3), Pretty Cure: The B...
# 34     60    21:00  {Yaoi Madlibs, Urusei Yatsura (Season 3), Pret...
# 35     62    21:30  {Lolita Hell: The Bad, the Cringe, and the Ita...
# 36     64    22:00  {Chained Soldier (18+), Lolita Hell: The Bad, ...
# 37     66    22:30  {Chained Soldier (18+), Hentai by Women, for W...
# 38     67    22:45  {Chained Soldier (18+), Hentai by Women, for W...
# 39     68    23:00  {Cosplay Horror Stories (18+), Chained Soldier...
# 40     70    23:30  {Cosplay Horror Stories (18+), Chained Soldier...
# 41     71    23:45  {Cosplay Horror Stories (18+), Chained Soldier...
